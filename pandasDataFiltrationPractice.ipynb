# %%
import pandas as pd

# %%
dt = pd.read_csv("Soil Nutrients.csv")

# %%
dt.head()
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 0  Strawberry  Moderate       Day Neutral    20.887923  747.860765  6.571548
# 1  Strawberry  Moderate       Day Neutral    18.062721  711.104329  6.251806
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 0    13.091483       533.762876  91.197196  170.800381  118.670058
# 1    13.063016       505.789101  91.939623  179.290364  121.020244
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
dt.shape
# Out:
# (15400, 19)

# %%
print(f"Max of Yield: {dt['Yield'].max()}")
print(f"Min of Yield: {dt['Yield'].min()}")
# Out:
# Max of Yield: 66.6192416580181
# Min of Yield: 0.770212659907174

# %%
dt1 = dt[dt['Rh'] <80]
print(dt1)
# Out:
#              Name Fertility       Photoperiod  Temperature     Rainfall  \
# 2100      Arugula  Moderate       Day Neutral    21.548532   699.563355
# 2101      Arugula  Moderate  Short Day Period    19.298389   749.428170
# 2102      Arugula  Moderate       Day Neutral    18.991317   656.690373
# 2103      Arugula  Moderate  Short Day Period    20.419960   709.012173
# 2104      Arugula  Moderate  Short Day Period    18.801426   814.762481
# ...           ...       ...               ...          ...          ...
# 15395  Green Peas  Moderate  Short Day Period    18.237489  1079.572958
# 15396  Green Peas  Moderate  Short Day Period    16.603638   958.201820
# 15397  Green Peas  Moderate  Short Day Period    12.154144   947.899222
# 15398  Green Peas  Moderate  Short Day Period    17.493029   863.902923
# 15399  Green Peas  Moderate  Short Day Period    19.874206  1019.356655
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
dt2=dt.query('pH < 5.5')
print(dt2)
# Out:
#              Name Fertility       Photoperiod  Temperature     Rainfall  \
# 1522       Grapes  Moderate  Short Day Period    17.510842   806.907866
# 1646       Grapes  Moderate       Day Neutral    21.246273   783.093813
# 1793       Grapes  Moderate  Short Day Period    23.328619   760.072030
# 5637         Kale      High  Short Day Period    18.985243   644.664297
# 5735         Kale      High       Day Neutral    19.499385   593.311074
# ...           ...       ...               ...          ...          ...
# 13289    Potatoes  Moderate  Short Day Period    20.258813   591.551298
# 13292    Potatoes  Moderate  Short Day Period    19.555164   669.406051
# 13293    Potatoes  Moderate  Short Day Period    19.181854   617.504468
# 13297    Potatoes  Moderate  Short Day Period    21.402637   670.301800
# 15333  Green Peas  Moderate  Short Day Period    19.152853  1049.068769
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
dt2
# Out:
#              Name Fertility       Photoperiod  Temperature     Rainfall  \
# 1522       Grapes  Moderate  Short Day Period    17.510842   806.907866
# 1646       Grapes  Moderate       Day Neutral    21.246273   783.093813
# 1793       Grapes  Moderate  Short Day Period    23.328619   760.072030
# 5637         Kale      High  Short Day Period    18.985243   644.664297
# 5735         Kale      High       Day Neutral    19.499385   593.311074
# ...           ...       ...               ...          ...          ...
# 13289    Potatoes  Moderate  Short Day Period    20.258813   591.551298
# 13292    Potatoes  Moderate  Short Day Period    19.555164   669.406051
# 13293    Potatoes  Moderate  Short Day Period    19.181854   617.504468
# 13297    Potatoes  Moderate  Short Day Period    21.402637   670.301800
# 15333  Green Peas  Moderate  Short Day Period    19.152853  1049.068769
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
dt3=dt.query('pH < 5.5' or 'pH > 5.3')

# %%
dt3
# Out:
#              Name Fertility       Photoperiod  Temperature     Rainfall  \
# 1522       Grapes  Moderate  Short Day Period    17.510842   806.907866
# 1646       Grapes  Moderate       Day Neutral    21.246273   783.093813
# 1793       Grapes  Moderate  Short Day Period    23.328619   760.072030
# 5637         Kale      High  Short Day Period    18.985243   644.664297
# 5735         Kale      High       Day Neutral    19.499385   593.311074
# ...           ...       ...               ...          ...          ...
# 13289    Potatoes  Moderate  Short Day Period    20.258813   591.551298
# 13292    Potatoes  Moderate  Short Day Period    19.555164   669.406051
# 13293    Potatoes  Moderate  Short Day Period    19.181854   617.504468
# 13297    Potatoes  Moderate  Short Day Period    21.402637   670.301800
# 15333  Green Peas  Moderate  Short Day Period    19.152853  1049.068769
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
sr = dt.iloc[2:6]

# %%
sr
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
# 5  Strawberry  Moderate  Short Day Period    18.655319  717.328188  6.481891
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
# 5    12.607460       495.907390  93.009123  182.237240  122.624012
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# 2  242.699601  19.158847  low_acidic      Loam  Summer     10.0     10.0
# 3  237.096892  20.265745  low_acidic      Loam  Summer     10.0     10.0
# ...

# %%
sr = dt.iloc[2:6,3:13]
#           rows,columns

# %%
sr
# Out:
#    Temperature    Rainfall        pH  Light_Hours  Light_Intensity         Rh  \
# 2    16.776782  774.038247  6.346916    12.945927       512.985617  91.387286
# 3    14.281000  665.633506  6.259598    13.318922       484.860067  91.254598
# 4    21.444490  806.531455  6.384368    13.312915       512.747307  92.354829
# 5    18.655319  717.328188  6.481891    12.607460       495.907390  93.009123
#
#      Nitrogen  Phosphorus   Potassium      Yield
# 2  181.440732  116.936806  242.699601  19.158847
# 3  176.165282  122.233153  237.096892  20.265745
# 4  182.935334  126.088234  243.880364  20.397336
# 5  182.237240  122.624012  239.459955  19.779821

# %% [markdown]
# loc includes the end point value , iloc does not

# %%
sc = dt.loc[2:6]

# %%
sc
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
# 5  Strawberry  Moderate  Short Day Period    18.655319  717.328188  6.481891
# 6  Strawberry  Moderate  Short Day Period    16.790311  779.629930  6.413393
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
# 5    12.607460       495.907390  93.009123  182.237240  122.624012
# 6    13.500056       464.846855  92.529800  163.246492  123.320220
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
sp = dt.loc[2:10,['Name','pH','Rh']]

# %%
sp
# Out:
#           Name        pH         Rh
# 2   Strawberry  6.346916  91.387286
# 3   Strawberry  6.259598  91.254598
# 4   Strawberry  6.384368  92.354829
# 5   Strawberry  6.481891  93.009123
# 6   Strawberry  6.413393  92.529800
# 7   Strawberry  6.448947  92.671838
# 8   Strawberry  6.750672  91.931189
# 9   Strawberry  6.320742  91.035197
# 10  Strawberry  6.527501  92.469314

# %%
dt.query('Rainfall < 600' and 'Rh > 96')
# Out:
#            Name Fertility       Photoperiod  Temperature     Rainfall  \
# 2800       Beet      High  Short Day Period    18.117918   770.682321
# 2801       Beet      High  Short Day Period    17.747869   639.490364
# 2802       Beet      High  Short Day Period    19.263801   726.052787
# 2803       Beet      High  Short Day Period    22.368768   714.472333
# 2804       Beet      High  Short Day Period    19.048828   681.228104
# ...         ...       ...               ...          ...          ...
# 7618  Radicchio  Moderate  Short Day Period    21.886739  2039.639252
# 7630  Radicchio  Moderate  Short Day Period    15.309980  1791.440448
# 7645  Radicchio  Moderate  Short Day Period    19.850471  2177.596177
# 7663  Radicchio  Moderate  Short Day Period    20.150645  1941.571209
# 7686  Radicchio  Moderate  Short Day Period    18.012964  2091.499828
#
#             pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
dt.query('Rainfall < 600' or 'Rh < 92')
# Out:
#              Name Fertility       Photoperiod  Temperature    Rainfall  \
# 700    Watermelon      High  Short Day Period    35.563270  586.947413
# 701    Watermelon      High  Short Day Period    36.921784  599.045438
# 703    Watermelon      High  Short Day Period    37.450067  588.696922
# 711    Watermelon      High  Short Day Period    35.091384  580.516762
# 714    Watermelon      High  Short Day Period    34.712947  597.132276
# ...           ...       ...               ...          ...         ...
# 13265    Potatoes  Moderate  Short Day Period    21.267154  596.706905
# 13274    Potatoes  Moderate  Short Day Period    20.452898  527.384299
# 13278    Potatoes  Moderate  Short Day Period    20.658737  591.944063
# 13289    Potatoes  Moderate  Short Day Period    20.258813  591.551298
# 14022    Broccoli      High  Short Day Period    19.210494  572.384806
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
fd = dt[dt['Nitrogen'] > 199]
print(fd)
# Out:
#              Name Fertility       Photoperiod  Temperature    Rainfall  \
# 338    Strawberry  Moderate       Day Neutral    18.466664  846.051600
# 3516        Chard      High  Short Day Period    23.343679  729.075840
# 3518        Chard      High  Short Day Period    21.578580  684.678317
# 3556        Chard      High  Short Day Period    20.842293  700.456929
# 3557        Chard      High       Day Neutral    22.147026  724.037151
# ...           ...       ...               ...          ...         ...
# 13288    Potatoes  Moderate  Short Day Period    18.033163  730.870100
# 13291    Potatoes  Moderate  Short Day Period    18.926253  706.371051
# 13293    Potatoes  Moderate  Short Day Period    19.181854  617.504468
# 13296    Potatoes  Moderate  Short Day Period    17.867522  629.700608
# 13297    Potatoes  Moderate  Short Day Period    21.402637  670.301800
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
ai = dt.at[13296,'Rh']
#           row, column     
# Accesing speciefic data

# %%
ai
# Out:
# 71.2262144438481

# %% [markdown]
# Adding new Column

# %%
sp.head()
# Out:
#          Name        pH         Rh
# 2  Strawberry  6.346916  91.387286
# 3  Strawberry  6.259598  91.254598
# 4  Strawberry  6.384368  92.354829
# 5  Strawberry  6.481891  93.009123
# 6  Strawberry  6.413393  92.529800

# %%
sp['kh'] = sp['pH']*0.6+sp['Rh']

# %%
sp.head()
# Out:
#          Name        pH         Rh         kh
# 2  Strawberry  6.346916  91.387286  95.195435
# 3  Strawberry  6.259598  91.254598  95.010357
# 4  Strawberry  6.384368  92.354829  96.185450
# 5  Strawberry  6.481891  93.009123  96.898258
# 6  Strawberry  6.413393  92.529800  96.377836

# %%
sp.insert(1, 'Ch', sp['pH'] * 0.1)

# %%
sp.head()
# Out:
#          Name        Ch        pH         Rh         kh
# 2  Strawberry  0.634692  6.346916  91.387286  95.195435
# 3  Strawberry  0.625960  6.259598  91.254598  95.010357
# 4  Strawberry  0.638437  6.384368  92.354829  96.185450
# 5  Strawberry  0.648189  6.481891  93.009123  96.898258
# 6  Strawberry  0.641339  6.413393  92.529800  96.377836

# %%
import numpy as np

# %%
sp['cprk']=np.where(sp['Ch'] >0.639 , 0 , 1)

# %%
sp.head()
# Out:
#          Name        Ch        pH         Rh         kh  cprk
# 2  Strawberry  0.634692  6.346916  91.387286  95.195435     1
# 3  Strawberry  0.625960  6.259598  91.254598  95.010357     1
# 4  Strawberry  0.638437  6.384368  92.354829  96.185450     1
# 5  Strawberry  0.648189  6.481891  93.009123  96.898258     0
# 6  Strawberry  0.641339  6.413393  92.529800  96.377836     0

# %%
sp['01'] = sp['Rh']>92

# %%
sp.head()
# Out:
#          Name        Ch        pH         Rh         kh  cprk     01
# 2  Strawberry  0.634692  6.346916  91.387286  95.195435     1  False
# 3  Strawberry  0.625960  6.259598  91.254598  95.010357     1  False
# 4  Strawberry  0.638437  6.384368  92.354829  96.185450     1   True
# 5  Strawberry  0.648189  6.481891  93.009123  96.898258     0   True
# 6  Strawberry  0.641339  6.413393  92.529800  96.377836     0   True

# %%
dkk = pd.read_csv("Soil Nutrients.csv")

# %%
dkk
# Out:
#              Name Fertility       Photoperiod  Temperature     Rainfall  \
# 0      Strawberry  Moderate       Day Neutral    20.887923   747.860765
# 1      Strawberry  Moderate       Day Neutral    18.062721   711.104329
# 2      Strawberry  Moderate  Short Day Period    16.776782   774.038247
# 3      Strawberry  Moderate  Short Day Period    14.281000   665.633506
# 4      Strawberry  Moderate       Day Neutral    21.444490   806.531455
# ...           ...       ...               ...          ...          ...
# 15395  Green Peas  Moderate  Short Day Period    18.237489  1079.572958
# 15396  Green Peas  Moderate  Short Day Period    16.603638   958.201820
# 15397  Green Peas  Moderate  Short Day Period    12.154144   947.899222
# 15398  Green Peas  Moderate  Short Day Period    17.493029   863.902923
# 15399  Green Peas  Moderate  Short Day Period    19.874206  1019.356655
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
sdk=dkk[dkk['Fertility']=='High']

# %%
sdk
# Out:
#              Name Fertility       Photoperiod  Temperature    Rainfall  \
# 700    Watermelon      High  Short Day Period    35.563270  586.947413
# 701    Watermelon      High  Short Day Period    36.921784  599.045438
# 702    Watermelon      High  Short Day Period    35.018391  685.574228
# 703    Watermelon      High  Short Day Period    37.450067  588.696922
# 704    Watermelon      High  Short Day Period    35.961415  603.321092
# ...           ...       ...               ...          ...         ...
# 14695    Broccoli      High  Short Day Period    18.925396  704.415192
# 14696    Broccoli      High  Short Day Period    20.589090  928.617317
# 14697    Broccoli      High  Short Day Period    20.136745  823.725130
# 14698    Broccoli      High  Short Day Period    18.515526  928.545693
# 14699    Broccoli      High  Short Day Period    20.192656  938.182545
#
#              pH  Light_Hours  Light_Intensity         Rh    Nitrogen  \
# ...

# %%
dkk['Fertility'].unique()
# Out:
# array(['Moderate', 'High'], dtype=object)

# %%
dkk['Fertility'].value_counts()
# Out:
# Fertility
# High        9800
# Moderate    5600
# Name: count, dtype: int64
